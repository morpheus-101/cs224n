# %%
# this mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# enter the foldername in your Drive where you have saved the unzipped
FOLDERNAME = 'cs224n/assignment5'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# now that we've mounted your Drive, this ensures that|
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/cs224n/assignment5
# Out:
# /content/drive/My Drive/cs224n/assignment5

# %%
# %run -i 'sanity_check.py' 1e
# Out:
# --------------------------------------------------------------------------------
# Running Sanity Check for Question 1e: words2charindices()
# --------------------------------------------------------------------------------
# Running test on small list of sentences
# Running test on large list of sentences
# All Sanity Checks Passed for Question 1e: words2charindices()!
# --------------------------------------------------------------------------------

# %%
# %run -i 'sanity_check.py' 1f
# Out:
# --------------------------------------------------------------------------------
# Running Sanity Check for Question 1f: Padding
# --------------------------------------------------------------------------------
# Running test on a list of sentences
# Sanity Check Passed for Question 1f: Padding!
# --------------------------------------------------------------------------------

# %%
# %run -i 'sanity_check.py' 1j
# Out:
# --------------------------------------------------------------------------------
# Running Sanity Check for Question 1j: Model Embedding
# --------------------------------------------------------------------------------
# Sanity Check Passed for Question 1j: Model Embedding!
# --------------------------------------------------------------------------------

# %%
import sys
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

# %%
# !sh run.sh train_local_q1
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cpu
# begin Maximum Likelihood training
# epoch 2, iter 10, avg. loss 95.83, avg. ppl 120.51 cum. examples 20, speed 237.07 words/sec, time elapsed 1.69 sec
# epoch 4, iter 20, avg. loss 91.33, avg. ppl 96.20 cum. examples 40, speed 255.93 words/sec, time elapsed 3.25 sec
# epoch 6, iter 30, avg. loss 87.35, avg. ppl 78.86 cum. examples 60, speed 252.57 words/sec, time elapsed 4.83 sec
# epoch 8, iter 40, avg. loss 83.68, avg. ppl 65.64 cum. examples 80, speed 283.14 words/sec, time elapsed 6.25 sec
# epoch 10, iter 50, avg. loss 80.35, avg. ppl 55.55 cum. examples 100, speed 277.32 words/sec, time elapsed 7.69 sec
# epoch 12, iter 60, avg. loss 77.58, avg. ppl 48.39 cum. examples 120, speed 256.71 words/sec, time elapsed 9.25 sec
# epoch 14, iter 70, avg. loss 73.41, avg. ppl 39.27 cum. examples 140, speed 256.10 words/sec, time elapsed 10.81 sec
# ...

# %%
# !sh run.sh test_local_q1
# Out:
# load test source sentences from [./en_es_data/test_tiny.es]
# load test target sentences from [./en_es_data/test_tiny.en]
# load model from model.bin
# Decoding: 100% 4/4 [00:00<00:00, 23.29it/s]
# Corpus BLEU: 99.29792465574434

# %%
# %run -i 'sanity_check.py' 2a
# Out:
# --------------------------------------------------------------------------------
# Running Sanity Check for Question 2a: CharDecoder.__init__()
# --------------------------------------------------------------------------------
# Sanity Check Passed for Question 2a: CharDecoder.__init__()!
# --------------------------------------------------------------------------------

# %%
# %run -i 'sanity_check.py' 2b
# Out:
# --------------------------------------------------------------------------------
# Running Sanity Check for Question 2b: CharDecoder.forward()
# --------------------------------------------------------------------------------
# Sanity Check Passed for Question 2b: CharDecoder.forward()!
# --------------------------------------------------------------------------------

# %%
# %run -i 'sanity_check.py' 2c
# Out:
# --------------------------------------------------------------------------------
# Running Sanity Check for Question 2c: CharDecoder.train_forward()
# --------------------------------------------------------------------------------
# Sanity Check Passed for Question 2c: CharDecoder.train_forward()!
# --------------------------------------------------------------------------------

# %%
# %run -i 'sanity_check.py' 2d
# Out:
# --------------------------------------------------------------------------------
# Running Sanity Check for Question 2d: CharDecoder.decode_greedy()
# --------------------------------------------------------------------------------
# Sanity Check Passed for Question 2d: CharDecoder.decode_greedy()!
# --------------------------------------------------------------------------------

# %%
# !sh run.sh train_local_q2
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cpu
# begin Maximum Likelihood training
# epoch 2, iter 10, avg. loss 454.38, avg. ppl 7356953395.52 cum. examples 20, speed 179.01 words/sec, time elapsed 2.23 sec
# epoch 4, iter 20, avg. loss 351.76, avg. ppl 43495973.99 cum. examples 40, speed 192.01 words/sec, time elapsed 4.32 sec
# epoch 6, iter 30, avg. loss 335.79, avg. ppl 19567614.65 cum. examples 60, speed 187.95 words/sec, time elapsed 6.45 sec
# epoch 8, iter 40, avg. loss 329.28, avg. ppl 14132953.77 cum. examples 80, speed 208.85 words/sec, time elapsed 8.36 sec
# epoch 10, iter 50, avg. loss 324.14, avg. ppl 10931172.16 cum. examples 100, speed 207.82 words/sec, time elapsed 10.29 sec
# epoch 12, iter 60, avg. loss 319.10, avg. ppl 8493586.69 cum. examples 120, speed 189.43 words/sec, time elapsed 12.40 sec
# epoch 14, iter 70, avg. loss 315.50, avg. ppl 7094989.08 cum. examples 140, speed 186.02 words/sec, time elapsed 14.55 sec
# ...

# %%
# !sh run.sh test_local_q2
# Out:
# load test source sentences from [./en_es_data/test_tiny.es]
# load test target sentences from [./en_es_data/test_tiny.en]
# load model from model.bin
# Decoding: 100% 4/4 [00:00<00:00,  5.96it/s]
# Corpus BLEU: 99.29792465574434

# %%
# !sh run.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# epoch 1, iter 500, avg. loss 331.41, avg. ppl 160752743.68 cum. examples 16000, speed 4359.70 words/sec, time elapsed 64.37 sec
# epoch 1, iter 1000, avg. loss 270.98, avg. ppl 3883767.47 cum. examples 32000, speed 4369.67 words/sec, time elapsed 129.76 sec
# epoch 1, iter 1500, avg. loss 245.17, avg. ppl 1045937.58 cum. examples 48000, speed 4270.49 words/sec, time elapsed 196.04 sec
# epoch 1, iter 2000, avg. loss 222.33, avg. ppl 317263.94 cum. examples 64000, speed 4192.36 words/sec, time elapsed 263.02 sec
# epoch 1, iter 2000, cum. loss 267.47, cum. ppl 3782386.11 cum. examples 64000
# begin validation ...
# validation: iter 2000, dev. ppl 243032.410707
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# epoch 1, iter 2500, avg. loss 207.67, avg. ppl 126112.72 cum. examples 16000, speed 3997.59 words/sec, time elapsed 333.79 sec
# ...

# %%
# !sh run.sh test
# Out:
# load test source sentences from [./en_es_data/test.es]
# load test target sentences from [./en_es_data/test.en]
# load model from model.bin
# Decoding: 100% 8064/8064 [17:48<00:00,  7.55it/s]
# Corpus BLEU: 24.570361029427133
