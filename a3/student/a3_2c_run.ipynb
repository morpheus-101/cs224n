# %%
# this mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# enter the foldername in your Drive where you have saved the unzipped
FOLDERNAME = 'cs224n/a3/student'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/cs224n/a3/student
# Out:
# /content/drive/My Drive/cs224n/a3/student

# %%
# %run -i 'parser_transitions.py' part_c
# Out:
# SHIFT test passed!
# LEFT-ARC test passed!
# RIGHT-ARC test passed!
# parse test passed!

# %%
# %run -i 'parser_transitions.py' part_d
# Out:
# minibatch_parse test passed!

# %%
# %run -i 'run.py'
# Out:
# ================================================================================
# INITIALIZING
# ================================================================================
# Loading data...
# took 2.06 seconds
# Building parser...
# took 1.26 seconds
# Loading pretrained embeddings...
# took 2.73 seconds
# Vectorizing data...
# took 1.58 seconds
# Preprocessing training data...
#   0%|          | 0/1848 [00:00<?, ?it/s]
# took 43.24 seconds
# took 0.03 seconds
#
# ================================================================================
# TRAINING
# ================================================================================
# Epoch 1 out of 10
# 100%|██████████| 1848/1848 [04:01<00:00,  7.66it/s]
# Average Train Loss: 0.17144428929757505
# Evaluating on dev set
# 1445850it [00:00, 43231446.85it/s]
#   0%|          | 0/1848 [00:00<?, ?it/s]
# - dev UAS: 84.88
# New best dev UAS! Saving model.
#
# Epoch 2 out of 10
# 100%|██████████| 1848/1848 [03:59<00:00,  7.71it/s]
# Average Train Loss: 0.10986888128860946
# Evaluating on dev set
# 1445850it [00:00, 40789749.57it/s]
#   0%|          | 0/1848 [00:00<?, ?it/s]
# - dev UAS: 86.67
# New best dev UAS! Saving model.
#
# Epoch 3 out of 10
# 100%|██████████| 1848/1848 [03:58<00:00,  7.76it/s]
# Average Train Loss: 0.0951988328211977
# Evaluating on dev set
# 1445850it [00:00, 42373264.10it/s]
#   0%|          | 0/1848 [00:00<?, ?it/s]
# - dev UAS: 87.24
# New best dev UAS! Saving model.
#
# Epoch 4 out of 10
# 100%|██████████| 1848/1848 [04:01<00:00,  7.66it/s]
# Average Train Loss: 0.08632619276005792
# Evaluating on dev set
# 1445850it [00:00, 40919107.16it/s]
#   0%|          | 0/1848 [00:00<?, ?it/s]
# - dev UAS: 87.68
# New best dev UAS! Saving model.
#
# Epoch 5 out of 10
# 100%|██████████| 1848/1848 [04:07<00:00,  7.47it/s]
# Average Train Loss: 0.07945684705623042
# Evaluating on dev set
# 1445850it [00:00, 34759803.96it/s]
#   0%|          | 0/1848 [00:00<?, ?it/s]
# - dev UAS: 88.26
# New best dev UAS! Saving model.
#
# Epoch 6 out of 10
# 100%|██████████| 1848/1848 [04:07<00:00,  7.47it/s]
# Average Train Loss: 0.07393165304652088
# Evaluating on dev set
# 1445850it [00:00, 40135904.16it/s]
#   0%|          | 0/1848 [00:00<?, ?it/s]
# - dev UAS: 88.39
# New best dev UAS! Saving model.
#
# Epoch 7 out of 10
# 100%|██████████| 1848/1848 [04:10<00:00,  7.38it/s]
# Average Train Loss: 0.06919376459375863
# Evaluating on dev set
# 1445850it [00:00, 36928111.30it/s]
#   0%|          | 0/1848 [00:00<?, ?it/s]
# - dev UAS: 88.05
#
# Epoch 8 out of 10
# 100%|██████████| 1848/1848 [04:06<00:00,  7.50it/s]
# Average Train Loss: 0.06493502298523209
# Evaluating on dev set
# 1445850it [00:00, 40001414.47it/s]
#   0%|          | 0/1848 [00:00<?, ?it/s]
# - dev UAS: 88.24
#
# Epoch 9 out of 10
# 100%|██████████| 1848/1848 [04:09<00:00,  7.40it/s]
# Average Train Loss: 0.06112957768166413
# Evaluating on dev set
# 1445850it [00:00, 44787297.46it/s]
#   0%|          | 0/1848 [00:00<?, ?it/s]
# - dev UAS: 88.26
#
# Epoch 10 out of 10
# 100%|██████████| 1848/1848 [03:57<00:00,  7.77it/s]
# Average Train Loss: 0.057963886546188746
# Evaluating on dev set
# 1445850it [00:00, 42439688.71it/s]
# - dev UAS: 88.11
#
# ================================================================================
# TESTING
# ================================================================================
# Restoring the best model weights found on the dev set
# Final evaluation on test set
# 2919736it [00:00, 61531266.84it/s]
# - test UAS: 88.59
# Done!
